# %% [markdown]
# # Ollama를 이용한 LLaMA3 모델 사용

# %% [markdown]
# - conda pormpt 창에서 입력하면 챗봇처럼 쓸 수 있음: `ollama run llama3`

# %%
# !pip install ollama

# %% [markdown]
# ### 1. 간단한 질의

# %%
import ollama

prompt = "Explain AI in simple term"
response = ollama.generate(model='llama3', prompt=prompt)

# %%
response['response']
# Out:
# 'Artificial Intelligence (AI) is like a super smart computer that can think and learn like humans do. Here\'s a simple explanation:\n\n**What is AI?**\n\nAI refers to computers or machines that are programmed to perform tasks that typically require human intelligence, such as:\n\n1. Learning from experiences\n2. Reasoning and problem-solving\n3. Understanding natural language (like you\'re talking to me!)\n4. Recognizing patterns and making decisions\n\n**How does AI work?**\n\nImagine a computer with special software that can "see" and "understand" things like images, sounds, and text. This software is trained on large amounts of data, which helps it learn to recognize patterns and make connections.\n\nWhen you give an AI system a task or question, it uses its training data to:\n\n1. Analyze the situation\n2. Make predictions or decisions based on what it\'s learned\n3. Provide answers or take actions\n\n**Types of AI:**\n\nThere are several types of AI, including:\n\n1. **Rule-based systems**: These follow strict rules and instructions to perform tasks.\n2. **Machine learning**: This type of AI uses data and algorithms to learn from experiences and improve over time.\n3. **Deep learning**: A specialized form of machine learning that uses neural networks (inspired by the human brain!) to analyze complex data.\n\n**Examples of AI in action:**\n\n1. Virtual assistants like Siri, Alexa, or Google Assistant\n2. Self-driving cars and trucks\n3. Image recognition systems (e.g., facial recognition)\n4. Chatbots that help you with customer service or banking\n\nIn simple terms, AI is a computer program that can think, learn, and make decisions like humans do. It\'s becoming more intelligent and helpful every day!'

# %%
prompt = "안녕. AI를 한국어로 짧고 간결하게 설명해줘."
response = ollama.generate(model='llama3', prompt=prompt)

# %%
response['response']
# Out:
# '안녕하세요! AI(인공지능)는 컴퓨터가 самостоятно 생각하고 행동하는能力입니다. AI는 사람의 지식을 기반으로 학습하여 다양한 작업을 수행할 수 있습니다. 예를 들어, 언어 이해, 이미지 인식, 음성 인식 등 다양한 분야에서 적용됩니다. AI는 인간과 MACHINE의 중간 지점에 놓여 있습니다.'

# %% [markdown]
# ### 2. 입력 프롬프트에 따른 출력 변화

# %%
prompts = [
    "Explain AI in simple terms.",
    "What is artificial intelligence?",
    "Can you describe how AI works?",
    "Give me a short introduction to artificial intelligence."
]


response = [ollama.generate(model='llama3', prompt=prompt)['response'] for prompt in prompts]

# %%
for i, prompt in enumerate(prompts):
    print("[", prompt, "]")
    print(response[i])
    print("=" * 100)
# Out:
# [ Explain AI in simple terms. ]
# Artificial Intelligence (AI) is like a super smart computer that can think and learn like humans do.
#
# Imagine you're playing chess with a friend. You make moves, and your friend makes counter-moves. You're both trying to outsmart each other.
#
# An AI system is like an opponent that can play chess against you. But instead of just following rules, the AI learns from its mistakes and improves over time.
#
# Here's how it works:
#
# 1. **Programming**: Humans create a set of instructions or "rules" for the AI to follow.
# 2. **Data**: The AI is given lots of data (like chess moves) to learn from.
# 3. **Learning**: The AI analyzes the data, figures out patterns and relationships, and makes decisions based on that information.
# 4. **Improvement**: As the AI makes mistakes or learns new things, it adjusts its behavior to become better at making decisions.
#
# AI can be used for many tasks:
#
# * Recognizing faces in photos
# * Translating languages
# * Playing games like chess or Go
# * Helping self-driving cars navigate roads
# * Assisting doctors diagnose diseases
#
# The goal of AI is to create machines that can think and act like humans, but even better!
# ====================================================================================================
# [ What is artificial intelligence? ]
# Artificial intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:
#
# 1. Learning: AI systems can learn from data and improve their performance over time.
# 2. Reasoning: AI systems can draw conclusions based on given information and make decisions.
# 3. Problem-solving: AI systems can identify problems and develop solutions.
#
# AI involves a range of techniques, including machine learning, deep learning, natural language processing (NLP), computer vision, and robotics. These technologies enable AI systems to:
#
# 1. Analyze data: AI systems can process large amounts of data, identifying patterns, relationships, and insights.
# 2. Recognize patterns: AI systems can recognize patterns in data, such as images, speech, or text.
# 3. Make decisions: AI systems can make predictions, classify objects, or recommend actions based on the data they've analyzed.
# 4. Interact with humans: AI systems can interact with humans through voice assistants, chatbots, or graphical interfaces.
#
# Types of Artificial Intelligence:
#
# 1. **Narrow or Weak AI**: AI designed to perform a specific task, such as playing chess or recognizing faces.
# 2. **General or Strong AI**: AI that possesses human-like intelligence and can perform any intellectual task that a human can.
# 3. **Superintelligence**: AI that is significantly more intelligent than the best human minds.
#
# Applications of Artificial Intelligence:
#
# 1. **Healthcare**: AI-powered diagnostic tools, personalized medicine, and medical research.
# 2. **Finance**: AI-driven trading platforms, investment analysis, and risk management.
# 3. **Customer Service**: Chatbots, virtual assistants, and automated customer support systems.
# 4. **Manufacturing**: AI-powered manufacturing automation, quality control, and supply chain optimization.
# 5. **Transportation**: Self-driving cars, route optimization, and traffic management.
#
# The potential benefits of Artificial Intelligence include:
#
# 1. Increased efficiency
# 2. Improved decision-making
# 3. Enhanced productivity
# 4. Better customer experiences
# 5. New business opportunities
#
# However, AI also raises concerns about:
#
# 1. Job displacement
# 2. Bias in algorithms
# 3. Data privacy and security
# 4. Unintended consequences of AI decisions
#
# As AI continues to evolve, it's essential to understand its capabilities, limitations, and potential impacts on society.
# ====================================================================================================
# [ Can you describe how AI works? ]
# AI (Artificial Intelligence) is a broad field that encompasses various techniques to enable machines to perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. Here's a general overview of how AI works:
#
# **Machine Learning**
#
# One of the primary approaches in AI is machine learning, which involves training artificial neural networks (ANNs) on large datasets. ANNs are inspired by the structure and function of the human brain. They consist of interconnected nodes (neurons) that process inputs, perform calculations, and produce outputs.
#
# Here's a simplified example of how machine learning works:
#
# 1. **Data Collection**: Gather a dataset consisting of input-output pairs, such as images with corresponding labels.
# 2. **Model Training**: Feed the data into an ANN, which is initially random and untrained. The model learns by adjusting its weights and biases to minimize errors between predicted outputs and actual targets.
# 3. **Training Loop**: Iterate through the training process multiple times, refining the model's performance on the dataset.
# 4. **Testing**: Evaluate the trained model on a separate test set to measure its accuracy.
#
# **Types of Machine Learning**
#
# There are several types of machine learning:
#
# 1. **Supervised Learning**: The model is trained on labeled data to learn a specific mapping between inputs and outputs (e.g., image classification).
# 2. **Unsupervised Learning**: The model identifies patterns in unlabeled data, often clustering or dimensionality reduction (e.g., k-means clustering).
# 3. **Reinforcement Learning**: The model learns by interacting with an environment, receiving rewards or penalties for its actions (e.g., game-playing AI).
#
# **Other AI Techniques**
#
# In addition to machine learning, other AI techniques include:
#
# 1. **Rule-Based Systems**: Programs that use predefined rules to make decisions.
# 2. **Expert Systems**: Knowledge-based systems that mimic human expertise in a specific domain.
# 3. **Deep Learning**: A subfield of machine learning that uses neural networks with multiple layers to learn complex patterns (e.g., computer vision, natural language processing).
#
# **How AI is Applied**
#
# AI is applied in various domains, such as:
#
# 1. **Computer Vision**: Image and video analysis, object detection, facial recognition.
# 2. **Natural Language Processing**: Text understanding, sentiment analysis, language translation.
# 3. **Robotics**: Autonomous systems that can perform tasks like assembly, welding, or navigation.
# 4. **Healthcare**: Medical diagnosis, treatment planning, personalized medicine.
# 5. **Finance**: Risk management, investment advice, fraud detection.
#
# This is a high-level overview of AI and its various techniques. If you have specific questions or would like more information on a particular topic, feel free to ask!
# ====================================================================================================
# [ Give me a short introduction to artificial intelligence. ]
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:
#
# * Learning from experience
# * Problem-solving
# * Pattern recognition
# * Decision-making
# * Perception and understanding of the environment
#
# The goal of AI is to create machines that can think, learn, and behave like humans, but with much greater speed, accuracy, and consistency. AI systems use algorithms, data structures, and software to analyze and process information, make decisions, and take actions.
#
# There are many types of AI, including:
#
# * Narrow or Weak AI: Designed for a specific task, such as playing chess or recognizing faces.
# * General or Strong AI: Capable of performing any intellectual task that a human can do.
# * Superintelligence: Far surpassing human intelligence in terms of reasoning, problem-solving, and learning.
#
# AI is being applied in many areas, including:
#
# * Healthcare: Diagnosing diseases, analyzing medical images, and developing personalized treatment plans.
# * Finance: Predictive modeling, portfolio management, and fraud detection.
# * Customer Service: Chatbots and virtual assistants that can understand natural language and respond accordingly.
# * Robotics: Autonomous vehicles, robots that can perform tasks in industrial settings, and home appliances that can learn and adapt.
#
# The potential benefits of AI include:
#
# * Increased efficiency and productivity
# * Improved accuracy and decision-making
# * Enhanced customer experiences
# * New opportunities for entrepreneurship and job creation
#
# However, there are also concerns about the impact of AI on jobs, privacy, and ethics. As AI continues to evolve and become more integrated into our daily lives, it's essential to consider these implications and develop strategies for responsible AI development and deployment.
# ====================================================================================================

# %% [markdown]
# ### 3. 파라미터 조절

# %%
import ollama
import time


def generate_text_with_params(prompt, max_length=50, temperature=0.7, top_p=1):
    print(f"[promt: {prompt} | max_length({max_length}), temperature({temperature}), top_p({top_p})]")

    start_time = time.time()
    response = ollama.generate(
        model="llama3",
        prompt=prompt,
        options={
            "max_length":max_length,
            "temperature":temperature,
            "top_p":top_p
        }
    )
    end_time = time.time()

    print(response['response'])
    print(f'러닝타임: {end_time - start_time:.2f} 초')

    return response['response']

# %%
prompt = "오늘 저녁 메뉴 추천해줘"

max_lengths = [20, 50, 100]
temperatures = [0.3, 1.2]

for max_length in max_lengths:
    for temperature in temperatures:
        generate_text_with_params(prompt, max_length, temperature, top_p=1)
        print("=" * 100)
# Out:
# [promt: 오늘 저녁 메뉴 추천해줘 | max_length(20), temperature(0.3), top_p(1)]
# I'd be happy to recommend a dinner menu for you! 😊 Here are some options:
#
# **Option 1: Classic Comfort Food**
#
# * Grilled Chicken Breast with Honey Mustard Sauce
# * Roasted Garlic Mashed Potatoes
# * Steamed Broccoli with Lemon Butter
#
# **Option 2: International Flavors**
#
# * Korean-Style BBQ Beef Tacos (marinated beef, kimchi slaw, cilantro)
# * Saffron Rice Pilaf with toasted almonds and dried cranberries
# * Grilled Asparagus with lemon zest and parmesan cheese
#
# **Option 3: Quick & Easy**
#
# * One-Pot Pasta with Tomato Sauce, ground beef, and mozzarella cheese
# * Garlic Bread with a side of fresh berries
# * Simple Green Salad with vinaigrette dressing
#
# Which one sounds appealing to you? 🤔
# 러닝타임: 1.43 초
# ====================================================================================================
# [promt: 오늘 저녁 메뉴 추천해줘 | max_length(20), temperature(1.2), top_p(1)]
# I'd be happy to recommend a dinner menu for you today! 🍴 Considering it's now your turn to decide, I'll suggest three different options, each with its own unique flavors and cuisines. Which one catches your eye?
#
# **Option 1: Asian-Inspired Delight**
# * Grilled Chicken Satay with Peanut Sauce
# * Steamed Jasmine Rice
# * Stir-Fried Vegetables (Carrots, Bell Peppers, Snow Peas) with Soy Sauce and Garlic
#
# **Option 2: Hearty Italian Favorite**
# * Bolognese Beef Penne Pasta with Ground Beef and Tomatoes
# * Roasted Asparagus with Parmesan Cheese
# * Toasted Grilled Bread with Fresh Basil
#
# **Option 3: Spicy Latin Fusion**
# * Chicken Fajitas with Bell Peppers, Onions, and Spicy Salsa
# * Warm Flour Tortillas
# * Mexican Street Corn Salad (Avocado, Tomato, Cilantro) with Lime Juice Dressing
# * Creamy Black Beans and Mexican Rice
#
# Which one of these delicious options makes your heart skip a beat? Let me know if you have any questions or need further tweaks!
# 러닝타임: 1.94 초
# ====================================================================================================
# [promt: 오늘 저녁 메뉴 추천해줘 | max_length(50), temperature(0.3), top_p(1)]
# I'd be happy to recommend a dinner menu for you! 😊 Here are a few options:
#
# **Option 1: Classic Comfort Food**
#
# * Grilled chicken breast with roasted vegetables (carrots, broccoli, and bell peppers)
# * Creamy mashed potatoes
# * Garlic bread
#
# **Option 2: International Flair**
#
# * Korean-style BBQ beef with marinated bulgogi sauce
# * Steamed jasmine rice
# * Stir-fried kimchi and bean sprouts
#
# **Option 3: Light and Fresh**
#
# * Baked salmon fillet with lemon butter and herbs
# * Roasted asparagus and cherry tomatoes
# * Quinoa salad with mixed greens, feta cheese, and a citrus vinaigrette
#
# Which one of these options sounds appealing to you? 🤔
# 러닝타임: 1.30 초
# ====================================================================================================
# [promt: 오늘 저녁 메뉴 추천해줘 | max_length(50), temperature(1.2), top_p(1)]
# 😊 Today's dinner recommendation! 🥗 Based on your location and the availability of ingredients, I'll suggest some delicious menu options for you:
#
# **Option 1: Korean-style Fried Chicken**
# Marinate chicken pieces in a mixture of soy sauce, garlic, and ginger. Then, double-fry for crispy skin and juicy meat. Serve with spicy gochujang sauce and steamed rice.
#
# **Option 2: One-Pot Pasta**
# Cook pasta, cherry tomatoes, zucchini, bell peppers, and your favorite protein (e.g., chicken, beef, or tofu) in a rich tomato-based sauce. Add some heavy cream and grated Parmesan cheese for an extra creamy touch!
#
# **Option 3: Korean BBQ Beef Tacos**
# Marinate thinly sliced beef short ribs in a mixture of soy sauce, sugar, sesame oil, and garlic. Grill the beef and serve it in crispy tacos with kimchi slaw, cilantro, and lime crema.
#
# **Option 4: Simple yet Savory Miso Soup**
# In a comforting bowl, combine miso paste, dashi broth, and your favorite seasonal ingredients (e.g., tofu, mushrooms, carrots). Serve with steamed rice or noodles for a satisfying meal.
#
# Which option piques your interest? 🤔 Let me know if you have any dietary restrictions or preferences, and I'll provide more tailored suggestions! 😊
# 러닝타임: 2.31 초
# ====================================================================================================
# [promt: 오늘 저녁 메뉴 추천해줘 | max_length(100), temperature(0.3), top_p(1)]
# I'd be happy to recommend a dinner menu for you today! 😊
#
# Considering it's a lovely day, I'll suggest some light and refreshing options. Here are three different menu ideas:
#
# **Menu 1: Spring-Inspired Delight**
#
# * Grilled chicken breast with lemon-herb butter
# * Roasted asparagus with parmesan cheese
# * Quinoa salad with cherry tomatoes, cucumber, and balsamic vinaigrette
#
# **Menu 2: Comfort Food Revival**
#
# * Creamy tomato pasta bake with garlic bread
# * Pan-seared salmon with dill sauce and steamed broccoli
# * Garlic roasted sweet potato wedges
#
# **Menu 3: Global Fusion Feast**
#
# * Korean-style BBQ beef tacos with kimchi slaw and cilantro lime rice
# * Steamed edamame with sea salt and lemon
# * Spicy mango salsa with crispy tortilla chips
#
# Which menu catches your eye? Or feel free to modify any of these options to suit your taste preferences! 🍴
# 러닝타임: 1.71 초
# ====================================================================================================
# [promt: 오늘 저녁 메뉴 추천해줘 | max_length(100), temperature(1.2), top_p(1)]
# 🍴 Today's dinner menu recommendation 🎉
#
# Considering you didn't specify any specific cuisine or dietary restrictions, I'll provide three diverse options:
#
# 1. **Korean-Style Beef & Vegetable Stir-Fry**: Sizzling beef strips with colorful veggies (bell peppers, carrots, snap peas) tossed in a sweet soy sauce-based stir-fry sauce, served with steamed white rice or noodles.
# 2. **Mediterranean Chicken Shawarma Wrap**: Juicy chicken breast, roasted to perfection, wrapped in a crispy pita with creamy tzatziki yogurt sauce, crunchy cucumbers, and juicy red tomatoes. Serve with a side of flavorful hummus!
# 3. **Spaghetti Bolognese with Garlicky Greens**: Classic Italian comfort food: tender ground beef ragù (think spaghetti meatballs) served with twisted pasta strands and finished with fresh parsley, parmesan cheese, garlic, and love . Add a simple green salad for balance!
#
# Choose one of these options or feel free to ask me if you have any specific preferences/dietary requirements. 🌏
# 러닝타임: 1.81 초
# ====================================================================================================

# %% [markdown]
# ### 4. 응답에 특정 단어를 포함하도록 하기

# %%
def generate_text_with_word(prompt, required_word):
    print(f"[ Prompt: {prompt} | 포함할 단어: {required_word}]")

    prompt = prompt + f"<Please make sure to include the word '{required_word} in your response.'>"

    response = ollama.generate(model="llama3", prompt=prompt)

    res_txt = response['response']

    if required_word.lower() in res_txt.lower():
        print("✅✅✅성공✅✅✅")
    else:
        print("❌❌❌실패❌❌❌")

    return res_txt

# %%
test_cases = [
    # ("프롬프트", "포함할 단어")
    ("Describe the future of AI", "truck"),
    ("Tell me about space exploration", "Mars")
]

for prompt, required_word in test_cases:
    response = generate_text_with_word(prompt, required_word)
    print(F"Response: {response}")
    print("=" * 100)
# Out:
# [ Prompt: Describe the future of AI | 포함할 단어: truck]
# ✅✅✅성공✅✅✅
# Response: The future of AI! It's going to be a wild ride. As we continue to push the boundaries of artificial intelligence, I predict that it will become increasingly integrated into our daily lives. Here are some possible developments:
#
# 1. **AI-powered trucking**: With the rise of autonomous vehicles, self-driving trucks could revolutionize the logistics industry. Imagine AI-equipped rigs navigating highways and rural routes with precision, reducing accidents, and increasing efficiency.
# 2. **Personalized everything**: AI will learn to understand individual preferences, emotions, and behaviors, allowing for tailored recommendations in fields like healthcare, finance, and entertainment. Your AI-powered personal assistant might even suggest the perfect snack to fuel your morning trucking haul
# 3. **Intelligent cities**: Cities will become increasingly "smart" as AI is integrated into urban infrastructure, such as traffic management systems, public transportation, and energy grids. This will lead to more efficient use of resources, reduced congestion, and improved air quality.
# 4. **Advanced healthcare**: AI-powered diagnosis and treatment systems will become the norm, allowing doctors to focus on high-level decision-making and personalized patient care. Imagine AI-assisted trucks equipped with medical equipment, traveling to remote areas to provide life-saving treatments.
# 5. **Cybersecurity**: As AI becomes more pervasive, cybersecurity will play a crucial role in protecting our digital lives. AI-powered systems will detect and respond to threats in real-time, ensuring the integrity of sensitive data and preventing catastrophic breaches.
# 6. **Creative collaborations**: AI will collaborate with humans in creative fields like art, music, and literature, producing innovative works that blend human intuition with machine learning capabilities. Imagine an AI-generated truck stop diner menu featuring a fusion of traditional roadhouse fare and avant-garde culinary masterpieces
# 7. **Space exploration**: As we venture into the cosmos, AI will play a critical role in navigating space travel, monitoring celestial bodies, and even assisting human astronauts on long-duration missions.
# 8. **Education revolution**: AI-powered adaptive learning systems will transform the way we learn, providing personalized educational experiences tailored to individual students' needs, abilities, and interests. Imagine AI-driven trucks equipped with interactive educational modules, traveling to rural areas to bring high-quality education to underprivileged communities.
#
# These are just a few glimpses into the future of AI. As this technology continues to evolve, it will undoubtedly have a profound impact on various aspects of our lives, from transportation to healthcare and beyond.
# ====================================================================================================
# [ Prompt: Tell me about space exploration | 포함할 단어: Mars]
# ✅✅✅성공✅✅✅
# Response: Space exploration! The thrill of venturing into the unknown, pushing the boundaries of human knowledge and innovation. From the dawn of the Space Age to the present day, our species has been driven to explore and understand the vast expanse of space.
#
# One of the most fascinating destinations in our solar system is Mars, often referred to as the "Red Planet" due to its reddish hue. With its rocky terrain, towering mountains, and sprawling valleys, Mars offers a unique window into the early days of our own planet's formation. NASA's Curiosity rover, launched in 2011, has been exploring Mars since 2012, uncovering secrets about the Martian environment and searching for signs of life.
#
# But space exploration isn't just about visiting Mars (although that's certainly exciting!). Humanity has sent probes to every planet in our solar system, including Venus, Earth's scorching hot neighbor; Mercury, the smallest and innermost planet; and Jupiter, the gas giant. We've even ventured beyond our solar system, with NASA's Voyager 1 spacecraft being the most distant human-made object in space.
#
# Other notable milestones include:
#
# 1. The Apollo missions: Between 1969 and 1972, NASA successfully landed humans on the Moon six times, marking a major achievement in space exploration.
# 2. International Space Stations (ISS): Launched in 1998, the ISS is a habitable artificial satellite that orbits Earth, serving as a laboratory for scientific research and experimentation.
# 3. Mars rovers: In addition to Curiosity, NASA has sent several other robots to explore Mars, including Spirit, Opportunity, and Perseverance.
# 4. Private space companies: Entrepreneurs like Elon Musk's SpaceX and Jeff Bezos' Blue Origin are revolutionizing the industry with reusable rockets, commercial satellite launches, and even plans for human settlements on the Moon and Mars!
#
# As we continue to push the boundaries of space exploration, new discoveries and challenges arise. The search for extraterrestrial life, the study of dark matter and dark energy, and the quest for a sustainable presence in space are just a few examples of the exciting opportunities ahead.
#
# So, buckle up and join me on this thrilling journey through the vast expanse of space!
# ====================================================================================================

# %% [markdown]
# ### 5. 다국어 처리 실험

# %%
def generate_text_in_language(language, prompt):
    print(f"[ Language: {language} | Prompt: {prompt}]")
    
    response = ollama.generate(model="llama3", prompt=prompt)
    print(response['response'])
    print("=" * 100)

# %%
prompts = {
    "English": "Please recomment me one dinner menu today. Please answer in English",
    "한국어": "오늘 저녁 메뉴를 1가지만 추천해줘. 한국어로 대답해줘",
    "にほんご": "今日の夕食メニューを1つおすすめしてください。日本語で答えてください。",
    "中文": "请为今晚的晚餐推荐一款菜肴。请用中文回答。",
    "français": "Veuillez me recommander un menu pour le dîner aujourd'hui. Veuillez répondre en français."
}   # 언어 요청을 안들을수도 있음...;

for language, prompt in prompts.items():
    generate_text_in_language(language, prompt)
# Out:
# [ Language: English | Prompt: Please recomment me one dinner menu today. Please answer in English]
# Here's a delicious dinner menu I'd like to recommend:
#
# **Grilled Salmon with Lemon Herb Butter**
#
# * Grilled salmon fillet (6 oz) seasoned with salt, pepper, and lemon zest
# * Lemon herb butter sauce made with softened butter, freshly squeezed lemon juice, minced parsley, and chopped chives
# * Roasted Asparagus (6-8 spears) tossed with olive oil, salt, and pepper
# * Garlic Mashed Potatoes (1/2 cup) infused with roasted garlic and heavy cream
#
# **Why I recommend this menu:**
#
# * The grilled salmon is a great source of protein and omega-3 fatty acids, which are beneficial for heart health.
# * The lemon herb butter sauce adds a bright and citrusy flavor to the dish without overpowering the delicate taste of the salmon.
# * Roasted asparagus is a tasty and nutritious side dish that pairs well with the richness of the salmon and potatoes.
# * Garlic mashed potatoes are a comforting and flavorful accompaniment that complements the meal nicely.
#
# **Tips:**
#
# * Make sure to cook the salmon to your desired level of doneness. For medium-rare, cook for 4-5 minutes per side.
# * Adjust the amount of lemon juice in the herb butter sauce to your taste.
# * Consider adding a simple green salad with vinaigrette dressing as an additional side dish.
#
# Enjoy your dinner!
# ====================================================================================================
# [ Language: 한국어 | Prompt: 오늘 저녁 메뉴를 1가지만 추천해줘. 한국어로 대답해줘]
# 😊 오늘 저녁으로는 짜장면을 추천합니다! 짜장면은 한국식 패스트 푸드 중 하나로, 촉촰한 고추장소스와 tender한 면이 일체를 이루는 완벽한 조합입니다. 집에서 쉽게 요리할 수 있는 레시피도 많습니다. 해물기와 함께 먹으면 incluso 더 좋습니다! 🍜👌
# ====================================================================================================
# [ Language: にほんご | Prompt: 今日の夕食メニューを1つおすすめしてください。日本語で答えてください。]
# 😊 今日の夕食メニューとして、以下のような料理をオススミします。
#
# 「抹茶ラーメン」(Matcha Ramen)
#
# この料理は、春風のような新鮮な味と、抹茶の美しい青み色を組み合わせた、季節感のある一品です。抹茶が入った明るい湯に、スープの香りがとまるラーメンの麺、豚肉や野菜を加えて、完成させることで、この料理は春の夕食にぴったりのメニューとなります。
#
# この抹茶ラーメンは、日本の四季折れの中でもっとも新しい季節である春の夕食に向き得る一品です。
# ====================================================================================================
# [ Language: 中文 | Prompt: 请为今晚的晚餐推荐一款菜肴。请用中文回答。]
# 😊 今晚的晚餐，我推荐的是一个非常简单却很美味的菜肴：番茄鸡肉煲（Tomato Chicken Casserole）。
#
# 这是一个经典的家庭式菜肴，很适合今晚的晚餐。你需要准备一些基本的原材料，如：鸡胸肉、番茄、洋葱、奶油、面包 crumbs、盐和黑胡椒。
#
# 步骤如下：
#
# 1.先将鸡胸肉切成小块，炒香洋葱和番茄。
# 2.然后，将鸡肉和番茄混合，加入一些盐和黑胡椒 Seasoning。
# 3.接着，将面包 crumbs、奶油和一些水混合，制成一个浓稠的 roux。
# 4.最后，将 roux涂抹在一个大煲中，然后加上鸡肉和番茄 mixture，倒入烤箱内烘烤20-25分钟。
#
# 这道菜肴非常简单，却味道非常美好。番茄的甜味与鸡肉的绒绒感相互结合，非常适合今晚的晚餐。你可以和家人共享这个美味的晚餐，或者单独享用。这是一个非常好的选择！ 👍
# ====================================================================================================
# [ Language: français | Prompt: Veuillez me recommander un menu pour le dîner aujourd'hui. Veuillez répondre en français.]
# Bonjour ! Je serais ravi de vous suggérer un menu délicieux pour votre dîner d'aujourd'hui.
#
# Voici une proposition que je vous fais :
#
# * Pour l'appétitoir, j'invite à une soupe crémeuse aux épinards et au fromage bleu, avec des croutons croustillants et une touche de pimient.
# * Ensuite, pour le plat principal, je vous recommande un filet mignon grillé aux herbes, servit avec une sauce à la crème et des légumes sautés (brocolis, carottes, haricots verts).
# * Pour le dessert, pourquoi pas une tarte au chocolat chaud, avec une boule de glace vanille ? Ou un plateau de fromages variés, avec des fruits et des biscuits ?
#
# Cela vous plaît-il ? Ou avez-vous des préférences ou des envies spécifiques que je pourrais prendre en compte pour vous suggérer un menu personnalisé ?
# ====================================================================================================

# %% [markdown]
# ### LLaMA 모델을 이용한 간단한 대화 시스템
#
# - 사용자 입력 input() 이용
# - 응답 print()로 출력
# - 'exit' 입력 시 대화 종료

# %%
while True:
    input_ = input("입력하시오: ")
    if input_=='exit':
        print('채팅을 종료합니다.')
        break
    else: 
        print(f'질문: {input_}')
        response = ollama.generate(model="llama3", prompt=input_)
        print(f'답변: {response['response']}')
        print("=" * 100)
# Out:
# 입력: 안녕?
# 답변: 안녕하세요! 😊
# ====================================================================================================
# 입력: 대답 안해?
# 답변: I apologize if my previous response was not satisfactory! I'm here to help and want to make sure you have a great experience. Please feel free to ask me anything, and I'll do my best to respond promptly and accurately. What's on your mind? 😊
# ====================================================================================================
# 입력: 한글로 말해줘
# 답변: I'd be happy to communicate with you in Korean! 😊 What would you like to talk about? Do you have a specific question or topic in mind, or do you just want to chat? Let me know and I'll do my best to help! 🇰🇷
# ====================================================================================================
# 입력: 한글로 말하라고
# 답변: 😊 I'll respond in Korean. Please go ahead and ask your question or make a statement.
# ====================================================================================================
# 입력: 한국어로 대답해주시오
# 답변: 이제 한국어로 대답하겠습니다! 🙏
# ====================================================================================================
# 입력: 존댓말해야 알아듣냐?
# 답변: You want me to understand Korean formal speech, also known as "polite language" or "" (jeoneun jabat malhay-yo)? 😊
#
# In Korean culture, it's common to use polite language when speaking to someone who is older, in a position of authority, or showing respect. This type of speech is characterized by the use of honorifics, such as verb endings and word choice.
#
# If you'd like, I can try to respond using formal Korean language. Just let me know! 😊
# ====================================================================================================
# 채팅을 종료합니다.
