# %% [markdown]
# # 프로젝트 진행 공간
# - 데이터에 대한 전처리 과정을 포함해 주세요.
# - 독립 변수 간의 여러 유의미한 관계를 시각화 해주세요.
# - EDA를 통해 얻어진 인사이트를 작성해주세요.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import matplotlib
from sklearn.preprocessing import StandardScaler
# font_path = '/Users/hwangjunho/Desktop/encore_skn11/04_data-analysis/03_matplotlib/AppleSDGothicNeo.ttc'
# font = fm.FontProperties(fname=font_path).get_name()
# matplotlib.rc('font', family=font)

# %% [markdown]
# ## EDA 구간

# %% [markdown]
# 1. 데이터 로드
#     - 다양한 소스에서 데이터를 로드한다. (파일, 데이터베이스, API 등에서 데이터를 불러온다.)
#     - 데이터가 로드된 후에는 구조를 확인하기 위해 첫 몇 줄의 데이터를 출력해 본다.

# %%
import pandas as pd
import glob

# 연도별 CSV 파일 불러오기 
file_paths = glob.glob("data/*.csv")

# csv 파일 합치기
df_list = [pd.read_csv(file) for file in file_paths]
df = pd.concat(df_list, ignore_index=True)

# csv 파일 저장
df.to_csv("all.csv", index=False, encoding="utf-8")

# %% [markdown]
# 2. 데이터 구조 및 기초 통계 확인
#     - 데이터의 구조를 파악하기 위해 컬럼 정보와 데이터 타입을 확인한다.
#     - 데이터의 기본 통계 정보를 출력하여 각 변수의 분포와 특성을 살펴본다.
#     - df.head(), df.info(), df.describe() 등의 함수를 사용한다.

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      458 non-null    object
#  1   연도      458 non-null    int64
#  2   WAR     458 non-null    float64
#  3   득점      458 non-null    int64
#  4   안타      458 non-null    int64
#  5   2루타     458 non-null    int64
#  6   3루타     458 non-null    int64
#  7   홈런      458 non-null    int64
#  8   타점      458 non-null    int64
#  9   도루      406 non-null    float64
#  10  볼넷      458 non-null    int64
#  11  사구      458 non-null    int64
#  12  고의사구    458 non-null    int64
#  13  삼진      458 non-null    int64
#  14  병살      458 non-null    int64
#  15  희생타     458 non-null    int64
#  16  희생플라이   458 non-null    int64
#  17  타율      458 non-null    float64
#  18  출루      458 non-null    float64
#  19  장타      458 non-null    float64
#  20  OPS     458 non-null    float64
#  21  wRC+    458 non-null    float64
#  22  수상여부    458 non-null    int64
# dtypes: float64(7), int64(15), object(1)
# memory usage: 82.4+ KB
# None
#                 연도         WAR          득점          안타         2루타  \
# count   458.000000  458.000000  458.000000  458.000000  458.000000
# mean   2012.469432    3.204607   74.615721  136.303493   23.548035
# std       7.265528    1.693926   17.496131   24.684478    7.646947
# min    2000.000000   -0.660000   36.000000   71.000000    5.000000
# 25%    2006.000000    2.022500   61.000000  117.250000   18.000000
# 50%    2013.000000    3.030000   73.000000  133.500000   23.000000
# 75%    2019.000000    4.207500   88.000000  154.000000   29.000000
# max    2024.000000    9.040000  118.000000  202.000000   49.000000
#
#               3루타          홈런          타점          도루          볼넷  ...  \
# count  458.000000  458.000000  458.000000  406.000000  458.000000  ...
# mean     2.705240   13.148472   65.995633   15.492611   51.733624  ...
# std      2.420376    9.893072   25.073197   13.280030   16.397383  ...
# min      0.000000    0.000000   13.000000    0.000000   13.000000  ...
# 25%      1.000000    5.000000   47.000000    6.000000   41.000000  ...
# 50%      2.000000   12.000000   64.000000   11.000000   50.000000  ...
# 75%      4.000000   20.000000   83.000000   22.000000   62.000000  ...
# max     12.000000   53.000000  144.000000   66.000000  127.000000  ...
#
#                삼진          병살         희생타       희생플라이          타율          출루  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean    76.530568    8.692140    4.462882    4.240175    0.297544    0.373699
# std     25.108869    4.012451    5.212732    2.498832    0.028318    0.031660
# min     29.000000    1.000000    0.000000    0.000000    0.203000    0.279000
# 25%     58.000000    6.000000    0.000000    2.000000    0.279000    0.353000
# 50%     73.000000    8.000000    2.000000    4.000000    0.295000    0.372000
# 75%     90.000000   11.000000    7.000000    6.000000    0.317000    0.394000
# max    156.000000   23.000000   28.000000   13.000000    0.376000    0.503000
#
#                장타         OPS        wRC+        수상여부
# count  458.000000  458.000000  458.000000  458.000000
# mean     0.446148    0.819847  121.154367    0.163755
# std      0.078459    0.100332   25.546772    0.370458
# min      0.273000    0.593000   63.100000    0.000000
# 25%      0.385000    0.748000  103.325000    0.000000
# 50%      0.444000    0.813500  121.200000    0.000000
# 75%      0.495000    0.881500  137.600000    0.000000
# max      0.720000    1.198000  207.300000    1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# 3. 결측치 및 이상치 탐색
#     - 결측치(NaN) 값이 존재하는지 확인하고, 이를 처리하는 방법을 결정한다.
#     - 데이터에 존재하는 이상치(Outlier)를 탐지하고, 이를 어떻게 처리할지 결정한다.
#     - df.isnull().sum(), df.boxplot() 등의 함수를 활용한다.

# %% [markdown]
# 4. 데이터 시각화를 통한 탐색
#     - 데이터를 시각화하여 변수 간의 관계, 분포 등을 파악한다.
#     - 히스토그램, 박스플롯, 상관관계 행렬 등 다양한 그래프를 통해 데이터의 특성을 시각적으로 확인한다.
#     - sns.countplot(), sns.heatmap() 등의 함수를 사용한다.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x=df['수상여부'])
plt.title("수상 여부 분포")
plt.xlabel("수상 여부")
plt.ylabel("선수 수")
plt.show()

selected_features = ['WAR', '타율', '홈런', '장타', 'OPS', 'wRC+', '안타', '출루']

plt.figure(figsize=(10, 8))
sns.heatmap(df[selected_features].corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("특징 간의 상관관계")
plt.show()



print(df.isnull().sum())

# 그래프 생성
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
axes = axes.flatten()

for i, feature in enumerate(selected_features):
    sns.boxplot(y=df[feature], ax=axes[i])
    axes[i].set_title(f'{feature} 분포')

plt.tight_layout()
plt.show()



# # 선택한 지표
# selected_features = ['WAR', '타율', '홈런', '장타', 'OPS', 'wRC+', '안타', '출루']

# # 그래프 생성
# fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
# axes = axes.flatten()

# df['수상여부'] = df['수상여부'].astype(str)

# # 수상 여부에 따른 색상 지정
# palette = {"0": "blue", "1": "red"} 

# for i, feature in enumerate(selected_features):
#     sns.boxplot(data=df, x="수상여부", y=feature, ax=axes[i], palette=palette)
#     axes[i].set_title(f"{feature} 분포 (수상 여부별)")

# plt.tight_layout()
# plt.show()
# Out:
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53945 (\N{HANGUL SYLLABLE TEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51669 (\N{HANGUL SYLLABLE JING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 이름        0
# 연도        0
# WAR       0
# 득점        0
# 안타        0
# 2루타       0
# 3루타       0
# 홈런        0
# 타점        0
# 도루       52
# 볼넷        0
# 사구        0
# 고의사구      0
# 삼진        0
# 병살        0
# 희생타       0
# 희생플라이     0
# 타율        0
# 출루        0
# 장타        0
# OPS       0
# wRC+      0
# 수상여부      0
# dtype: int64
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8496\1812329280.py:27: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54856 (\N{HANGUL SYLLABLE HOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47088 (\N{HANGUL SYLLABLE REON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Playdata\anaconda3\envs\pystudy_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 도루 : 평균값으로 채워넣는다.
#
# 이상치 : 선수의 뛰어난 성과를 반영하는 경우가 많아, 데이터의 의미를 보존하기 위해 제거하지 않고 유지

# %% [markdown]
# 5. 데이터 정제 및 전처리
#     - 필요 없는 변수나 중복 데이터를 제거한다.
#     - 범주형 데이터를 처리하거나, 스케일링 및 정규화를 통해 모델에 적합한 형태로 데이터를 변환한다.
#     - df.drop(), df.fillna(), pd.get_dummies() 등의 함수를 활용한다.

# %%
df_new = df.drop(columns=['이름', '득점', '2루타', '3루타', '타점', '도루', '볼넷', '사구', '고의사구', '삼진', '병살', '희생타', '희생플라이'])
df_avg = pd.read_csv('yearly_averages.csv')
# display(df_avg)
# display(df_new)

merged = pd.merge(df_new, df_avg, on="연도", suffixes=('_all', '_avg'))

# display(merged)

columns_to_subtract = ['WAR', '타율', '홈런', '장타', 'OPS', 'wRC+', '안타', '출루']

for col in columns_to_subtract:
    merged[f'{col}'] = merged[f'{col}_all'] - merged[f'{col}_avg']

# 차이값만 모은 DataFrame 생성
df_diff = merged[['연도'] + [f'{col}' for col in columns_to_subtract]+['수상여부']]



df_diff = df_diff.drop(columns=['연도'])
# 결과 확인
# display(df_diff)

X = df_diff.drop(columns=['수상여부'])

y = df_diff['수상여부']

# 정규화
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# display(X_scaled, y)
# df_new[df_new['수상여부']==1].value_counts
print(df['수상여부'].value_counts())
# Out:
# 수상여부
# 0    383
# 1     75
# Name: count, dtype: int64

# %% [markdown]
# ## 학습 구간(knn)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# 학습/테스트 분리
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=55)

# 모델 정의 및 학습
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

# 예측
y_pred = model.predict(X_test)

# 결과 평가
print("정확도:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 정확도: 0.9043478260869565
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        96
#            1       0.83      0.53      0.65        19
#
#     accuracy                           0.90       115
#    macro avg       0.87      0.75      0.79       115
# weighted avg       0.90      0.90      0.90       115

# %%
# 원본 데이터에서 '이름' 컬럼 포함한 데이터 만들기
df_with_names = df[['이름', '연도', '수상여부'] + columns_to_subtract]

# '연도' 기준으로 yearly_averages와 병합
merged_with_names = pd.merge(df_with_names, df_avg, on="연도", suffixes=('_all', '_avg'))

# 차이값 계산
for col in columns_to_subtract:
    merged_with_names[f'{col}'] = merged_with_names[f'{col}_all'] - merged_with_names[f'{col}_avg']

# 필요한 컬럼 선택 (이름 포함)
df_diff_with_names = merged_with_names[['이름', '연도'] + [f'{col}' for col in columns_to_subtract] + ['수상여부']]

# '연도' 제외
df_diff_with_names = df_diff_with_names.drop(columns=['연도'])

# X, y 분리
X_with_names = df_diff_with_names.drop(columns=['이름', '수상여부'])
y_with_names = df_diff_with_names['수상여부']
names = df_diff_with_names['이름']  # 선수 이름 저장

# 정규화
scaler = StandardScaler()
X_scaled_with_names = scaler.fit_transform(X_with_names)

# 학습/테스트 분리 (선수 이름도 함께 분리)
X_train, X_test, y_train, y_test, names_train, names_test = train_test_split(
    X_scaled_with_names, y_with_names, names, test_size=0.25, random_state=55
) # 3, 55

# 모델 학습
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

# 예측
y_pred = model.predict(X_test)

# 결과 데이터프레임 생성
results_df = pd.DataFrame({
    '이름': names_test,
    '실제 수상여부': y_test.values,
    '예측 수상여부': y_pred
})

# 결과 출력
pd.set_option('display.max_rows', None)
print(results_df)

# 모델 성능 평가
print("정확도:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
#         이름  실제 수상여부  예측 수상여부
# 26     이병규        1        0
# 405    피렐라        1        1
# 386    구자욱        1        0
# 4      김재현        0        0
# 193    전준우        0        0
# 419    배정대        0        0
# 184    김주찬        0        0
# 389    전준우        0        1
# 332    이명기        0        0
# 294    양성우        0        0
# 340    이정후        1        1
# 33     김수연        0        0
# 177    송지만        0        0
# 218    이진영        0        0
# 30     박한이        0        0
# 119    이진영        0        0
# 214    민병헌        0        0
# 155    이택근        1        0
# 377    조용호        0        0
# 409    김현수        0        0
# 450    페라자        0        0
# 85     송지만        0        0
# 180   가르시아        0        0
# 261    아두치        0        0
# 258    유한준        1        1
# 63     조경환        0        0
# 53     정수근        0        0
# 291    이택근        0        0
# 264    손아섭        0        0
# 69     전상렬        0        0
# 249    나지완        0        0
# 168    임재철        0        0
# 401     터커        0        0
# 233    권희동        0        0
# 403    이정후        1        1
# 293    김호령        0        0
# 212    전준우        0        0
# 41     이종범        1        0
# 321    한동민        0        0
# 325    구자욱        0        0
# 230    조동화        0        0
# 370    박건우        0        0
# 320    이정후        1        0
# 72     심재학        0        0
# 27     이영우        0        0
# 196   알드리지        0        0
# 190    강동우        0        0
# 81     심정수        0        0
# 38     이영우        0        1
# 392    박해민        0        0
# 70     박한이        1        1
# 20     김재현        0        0
# 34     김대익        0        0
# 410    박해민        0        0
# 267    박용택        0        0
# 238    나성범        1        1
# 6      이병규        1        0
# 284    대니돈        0        0
# 200    김원섭        0        0
# 323   버나디나        0        0
# 25     전준호        0        0
# 336    김동엽        0        0
# 440    구자욱        1        1
# 84     페레즈        0        0
# 64     전준호        0        0
# 315    전준우        1        1
# 271    이종욱        0        0
# 277    손아섭        0        0
# 159    김원섭        0        0
# 213    이병규        0        0
# 117    박재홍        0        0
# 235    장기영        0        0
# 96     클리어        0        0
# 287    고종욱        0        0
# 385    알테어        0        0
# 391    추신수        0        0
# 223    나성범        0        0
# 327    박해민        0        0
# 126    이용규        0        0
# 436    피렐라        0        0
# 455    배정대        0        0
# 191    김현수        0        0
# 57     양준혁        1        1
# 329    노수광        0        0
# 86     전상렬        0        0
# 106    정수성        0        0
# 8      스미스        0        0
# 15     김종훈        0        0
# 68     장원진        0        0
# 48   마르티네스        0        0
# 128    발데스        0        0
# 269   스나이더        0        0
# 257    조동화        0        0
# 260    나성범        1        0
# 104    이용규        0        0
# 231    정현석        0        0
# 217    최형우        1        0
# 151    추승우        0        0
# 133    송지만        0        0
# 95     이병규        1        1
# 282    박건우        0        0
# 358    김강민        0        0
# 199    이용규        1        0
# 182    김원섭        0        0
# 62   마르티네스        0        0
# 67     박용택        0        0
# 232    신종길        0        0
# 335    김헌곤        0        0
# 139    이용규        0        0
# 91     박재홍        0        0
# 322    채은성        0        0
# 121    강동우        0        0
# 457    한유섬        0        0
# 349    손아섭        0        0
# 13     조경환        0        0
# 정확도: 0.9043478260869565
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        96
#            1       0.83      0.53      0.65        19
#
#     accuracy                           0.90       115
#    macro avg       0.87      0.75      0.79       115
# weighted avg       0.90      0.90      0.90       115
